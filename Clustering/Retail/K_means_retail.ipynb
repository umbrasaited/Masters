# %%
from google.colab import drive
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Number of principal components selected: 4

# %%
pca = PCA(n_components = 4)
#fitting the model to the data with the selected number of components
pca.fit_transform(X)
scores_pca = pca.transform(X)

# %%
#fit KMeans using the transformed data from the PCA
wcss=[]
for i in range(2,11):
  kmeans_pca = KMeans(n_clusters=i, init='k-means++',random_state=42)
  kmeans_pca.fit(scores_pca)
  cluster_labels = kmeans_pca.labels_
  silhouette = silhouette_score(scores_pca, cluster_labels)
  calinski = calinski_harabasz_score(scores_pca, cluster_labels)
  davies = davies_bouldin_score(scores_pca, cluster_labels)
  wcss.append(kmeans_pca.inertia_)

  # Count points in each cluster
  cluster_sizes = np.bincount(cluster_labels)
  cluster_percentages = (cluster_sizes / len(cluster_labels)) * 100

  print(f"Number of clusters: {i}")
  print("Percentage of points in each cluster:", end=" ")
  for j, percentage in enumerate(cluster_percentages):
        print(f"Cluster {j}: {percentage:.1f}%", end=" ")
  print()  # New line after percentages
  print(f"Silhouette Coefficient: {silhouette:.4f}",
          f"Calinski-Harabasz Index: {calinski:.4f}",
          f"Davies-Bouldin Index: {davies:.4f}")
  print("-" * 50)  # Add a separator line between iterations
# Out:
# Number of clusters: 2
# Percentage of points in each cluster: Cluster 0: 67.1% Cluster 1: 32.9%
# Silhouette Coefficient: 0.5625 Calinski-Harabasz Index: 226817.7895 Davies-Bouldin Index: 0.6976
# --------------------------------------------------
# Number of clusters: 3
# Percentage of points in each cluster: Cluster 0: 33.7% Cluster 1: 32.8% Cluster 2: 33.5%
# Silhouette Coefficient: 0.3266 Calinski-Harabasz Index: 148608.2005 Davies-Bouldin Index: 1.2636
# --------------------------------------------------
# Number of clusters: 4
# Percentage of points in each cluster: Cluster 0: 33.6% Cluster 1: 9.8% Cluster 2: 33.5% Cluster 3: 23.0%
# Silhouette Coefficient: 0.2598 Calinski-Harabasz Index: 121525.5335 Davies-Bouldin Index: 1.3876
# --------------------------------------------------
# Number of clusters: 5
# Percentage of points in each cluster: Cluster 0: 35.1% Cluster 1: 9.1% Cluster 2: 30.7% Cluster 3: 22.3% Cluster 4: 2.8%
# Silhouette Coefficient: 0.2754 Calinski-Harabasz Index: 105574.7713 Davies-Bouldin Index: 1.2557
# --------------------------------------------------
# Number of clusters: 6
# Percentage of points in each cluster: Cluster 0: 23.9% Cluster 1: 9.1% Cluster 2: 21.2% Cluster 3: 22.3% Cluster 4: 2.8% Cluster 5: 20.7%
# Silhouette Coefficient: 0.2773 Calinski-Harabasz Index: 102959.7144 Davies-Bouldin Index: 1.1480
# --------------------------------------------------
# Number of clusters: 7
# Percentage of points in each cluster: Cluster 0: 21.8% Cluster 1: 9.1% Cluster 2: 15.5% Cluster 3: 22.3% Cluster 4: 1.5% Cluster 5: 18.2% Cluster 6: 11.6%
# Silhouette Coefficient: 0.2672 Calinski-Harabasz Index: 94032.9169 Davies-Bouldin Index: 1.1585
# --------------------------------------------------
# Number of clusters: 8
# Percentage of points in each cluster: Cluster 0: 20.0% Cluster 1: 14.4% Cluster 2: 15.0% Cluster 3: 7.7% Cluster 4: 15.4% Cluster 5: 15.5% Cluster 6: 9.2% Cluster 7: 2.8%
# Silhouette Coefficient: 0.2325 Calinski-Harabasz Index: 89672.6670 Davies-Bouldin Index: 1.2309
# --------------------------------------------------
# Number of clusters: 9
# Percentage of points in each cluster: Cluster 0: 18.2% Cluster 1: 14.4% Cluster 2: 17.1% Cluster 3: 7.7% Cluster 4: 17.7% Cluster 5: 1.3% Cluster 6: 9.2% Cluster 7: 1.5% Cluster 8: 12.8%
# Silhouette Coefficient: 0.2444 Calinski-Harabasz Index: 88366.0396 Davies-Bouldin Index: 1.1335
# --------------------------------------------------
# Number of clusters: 10
# Percentage of points in each cluster: Cluster 0: 15.6% Cluster 1: 14.4% Cluster 2: 16.3% Cluster 3: 7.7% Cluster 4: 6.7% Cluster 5: 15.7% Cluster 6: 9.2% Cluster 7: 1.5% Cluster 8: 11.5% Cluster 9: 1.3%
# Silhouette Coefficient: 0.2459 Calinski-Harabasz Index: 85624.6899 Davies-Bouldin Index: 1.1273
# --------------------------------------------------

# %%
plt.figure(figsize = (10,8))
plt.plot(range(2,11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %% [markdown]
# Number of clusters selected: 2

# %%
#Kmeans run with the selected number of clusters
#initialize with the random state
kmeans_pca = KMeans(n_clusters=2, init='k-means++', random_state=42)
#fitting the data with the kmeans pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
#new data frame is created with the original features and adding the PCA scores and assigned clusters
df_segm_pca_kmeans = pd.concat([X.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
df_segm_pca_kmeans.columns.values[-4: ] = ['Component 1', 'Component 2', 'Component 3', 'Component 4']
#last added column contains the pca kmeans clustering labels
df_segm_pca_kmeans['Segment K-Means PCA'] = kmeans_pca.labels_
df_segm_pca_kmeans.head()

# %%
#create a new column named 'Segment' and map the added clustering direclty inside it
df_segm_pca_kmeans['Segment'] = df_segm_pca_kmeans['Segment K-Means PCA'].map({0:'1', 1:'2', 2:'3', 3:'4'})

#plotting the data by pca components. The Y axis is the 1st component, X axis is the 2nd
x_axis = df_segm_pca_kmeans['Component 2']
y_axis = df_segm_pca_kmeans['Component 1']
plt.figure(figsize = (10,8))
sns.scatterplot(x=x_axis, y=y_axis, hue = df_segm_pca_kmeans['Segment'], palette="deep")
plt.title('Clusters by PCA Components')
plt.show()

# %%
# Adding actual feature names
x_axis = df['avg_monthly_cash_transaction_amount']
y_axis = df['avg_monthly_cross_border_transaction_amount']

plt.figure(figsize=(10,8))
sns.scatterplot(x=x_axis, y=y_axis, hue=df_segm_pca_kmeans['Segment'], palette="deep")
plt.title('Clusters by Selected Features')
plt.xlabel('avg_monthly_cash_transaction_amount')
plt.ylabel('avg_monthly_cross_border_transaction_amount')
plt.show()
